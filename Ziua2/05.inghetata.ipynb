# %% [markdown]
# # pip install pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("date_inghetata.csv")
df
# Out:
#      temperatura  vanzari      luna zi_saptamana
# 0              8       25  ianuarie         luni
# 1             10       35  ianuarie        marti
# 2             12       45  ianuarie     miercuri
# 3             15       55  ianuarie          joi
# 4             18       75  ianuarie       vineri
# ..           ...      ...       ...          ...
# 233           33      168       mai     miercuri
# 234           35      182       mai          joi
# 235           37      195       mai       vineri
# 236           39      208       mai      sambata
# 237           41      222       mai    duminica
#
# [238 rows x 4 columns]

# %%
df = pd.read_csv("https://raw.githubusercontent.com/sojog/Machine-Learning-ADR-Infosec-26-29-30-ianuarie-2026/refs/heads/main/Ziua2/date_inghetata.csv")
df
# Out:
#      temperatura  vanzari      luna zi_saptamana
# 0              8       25  ianuarie         luni
# 1             10       35  ianuarie        marti
# 2             12       45  ianuarie     miercuri
# 3             15       55  ianuarie          joi
# 4             18       75  ianuarie       vineri
# ..           ...      ...       ...          ...
# 233           33      168       mai     miercuri
# 234           35      182       mai          joi
# 235           37      195       mai       vineri
# 236           39      208       mai      sambata
# 237           41      222       mai    duminica
#
# [238 rows x 4 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df["zi_saptamana"]
# Out:
# 0           luni
# 1          marti
# 2       miercuri
# 3            joi
# 4         vineri
#          ...
# 233     miercuri
# 234          joi
# 235       vineri
# 236      sambata
# 237    duminica
# Name: zi_saptamana, Length: 238, dtype: object

# %%
df[["zi_saptamana", "luna"]]
# Out:
#     zi_saptamana      luna
# 0           luni  ianuarie
# 1          marti  ianuarie
# 2       miercuri  ianuarie
# 3            joi  ianuarie
# 4         vineri  ianuarie
# ..           ...       ...
# 233     miercuri       mai
# 234          joi       mai
# 235       vineri       mai
# 236      sambata       mai
# 237    duminica        mai
#
# [238 rows x 2 columns]

# %%
x = df["temperatura"]
type(x)
x
# Out:
# 0       8
# 1      10
# 2      12
# 3      15
# 4      18
#        ..
# 233    33
# 234    35
# 235    37
# 236    39
# 237    41
# Name: temperatura, Length: 238, dtype: int64

# %%
x = df[["temperatura"]]
type(x)
x
# Out:
#      temperatura
# 0              8
# 1             10
# 2             12
# 3             15
# 4             18
# ..           ...
# 233           33
# 234           35
# 235           37
# 236           39
# 237           41
#
# [238 rows x 1 columns]

# %%
y = df[["vanzari"]]
type(y)
y
# Out:
#      vanzari
# 0         25
# 1         35
# 2         45
# 3         55
# 4         75
# ..       ...
# 233      168
# 234      182
# 235      195
# 236      208
# 237      222
#
# [238 rows x 1 columns]

# %%
#  1. Trebuie creat un scatter plot pentru a vizualiza relația dintre temperatură și vânzări.
plt.scatter(x, y)

# %%
from sklearn.model_selection import train_test_split

# %%
# 2. Trebuie să separi datele în variabila independentă (X) și variabila dependentă (y). Variabila independentă este temperatura, iar variabila dependentă este numărul de vânzări.

# 3. Împarte datele în seturi de antrenament și testare. Vei folosi 78% din date pentru antrenament și 22% pentru testare.

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.22)

# %%
plt.scatter(x_train, y_train)
plt.scatter(x_test, y_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor

# %%
# 4. Creează un model de regresie și antrenează-l pe datele de antrenament.
linear_model = LinearRegression()
linear_model
# Out:
# LinearRegression()

# %%
linear_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
linear_model.score(x_test, y_test)
# Out:
# 0.9755400616034624

# %%
# 5. Folosește modelul pentru a prezice vânzările pentru temperaturi noi pe care nu le-ai văzut înainte.

linear_model.predict(x_test)
# Out:
# array([[207.83089067],
#        [244.09754065],
#        [164.31091069],
#        [142.5509207 ],
#        [164.31091069],
#        [149.8042507 ],
#        [236.84421065],
#        [128.04426071],
#        [157.0575807 ],
#        [164.31091069],
#        [164.31091069],
#        [120.79093072],
#        [142.5509207 ],
#        [135.29759071],
#        [ 77.27095074],
#        [222.33755066],
#        [171.56424069],
#        [ 84.52428074],
#        [186.07090068],
#        [106.28427073],
#        [ 84.52428074],
#        [ 84.52428074],
#        [236.84421065],
#        [178.81757068],
#        [120.79093072],
#        [200.57756067],
#        [258.60420064],
#        [128.04426071],
#        [106.28427073],
#        [157.0575807 ],
#        [ 77.27095074],
#        [ 33.75097077],
#        [229.59088065],
#        [106.28427073],
#        [ 62.76429075],
#        [251.35087064],
#        [ 55.51096076],
#        [ 62.76429075],
#        [251.35087064],
#        [142.5509207 ],
#        [164.31091069],
#        [222.33755066],
#        [ 99.03094073],
#        [135.29759071],
#        [236.84421065],
#        [ 26.49764077],
#        [186.07090068],
#        [128.04426071],
#        [171.56424069],
#        [244.09754065],
#        [215.08422066],
#        [149.8042507 ],
#        [120.79093072]])

# %%
# 6. Compară scorul cu a unui alt model
knn_model = KNeighborsRegressor(n_neighbors=4)
knn_model
# Out:
# KNeighborsRegressor(n_neighbors=4)

# %%
knn_model.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=4)

# %%
knn_model.score(x_test, y_test)
# Out:
# 0.9886476519210236

# %% [markdown]
# ## Hiperparametri

# %%
scores = {}

for k in range(3,8):
    knn_model = KNeighborsRegressor(n_neighbors=k)
    knn_model.fit(x_train, y_train)
    score = knn_model.score(x_test, y_test)
    scores[k] = score
scores
# Out:
# {3: 0.9888217985570358,
#  4: 0.9886205997441514,
#  5: 0.9886476519210236,
#  6: 0.9898961942089147,
#  7: 0.9896550360499173}
