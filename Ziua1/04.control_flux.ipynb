# %%
if 10 > 3:
print("Adevarat") # indentare necesara (spatiu de la stanga)
# Out:
#   Cell In[7], line 2
#     print("Adevarat") # indentare necesara (spatiu de la stanga)
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
if 10 > 3:
 print("Adevarat") # nu e recomandat
# Out:
# Adevarat

# %%
if 10 > 3:
    print("Adevarat") # E recomandat
# Out:
# Adevarat

# %%
# cuvant cheie
if = 30
# Out:
#   Cell In[6], line 2
#     if = 30
#        ^
# SyntaxError: invalid syntax

# %%
if 10 > 3:
    print("Adevarat")
else:
    print("Fals")
# Out:
# Adevarat

# %%
if 10 < 3:
    print("Adevarat")
else:
    print("Fals")
# Out:
# Fals

# %%
else:              # nu poate sa existe singur
    print("Fals")
# Out:
#   Cell In[12], line 1
#     else:              # nu poate sa existe singur
#     ^
# SyntaxError: invalid syntax

# %%
varsta = 30

if varsta < 18:
    print("Minor")
else:
    if varsta < 30:
        print("Tanar")
    else:
        if varsta < 50:
            print("Adult")
        else:
            print("Pensionar")
# Out:
# Adult

# %%
varsta = 30

if varsta < 18:
    print("Minor")
elif varsta < 30:
    print("Tanar")
elif varsta < 50:
    print("Adult")
else:
    print("Pensionar")
# Out:
# Adult
