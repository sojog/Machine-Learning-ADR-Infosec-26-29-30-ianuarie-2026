# %%
o_lista = [1, 2, 3, "salut", True, 3.0]
print(type(o_lista))
# Out:
# <class 'list'>

# %%
len(o_lista)
# Out:
# 6

# %%
            # cheie : valoare
dictionar = { "rosu" : 1,
              "verde" : 2,
                "mov": 3,
            "negru" : "salut",
            "albastru" : True,
                "alb": 3.0}

# %%
len(dictionar)
# Out:
# 6

# %%
o_lista[4]
# Out:
# True

# %%
dictionar["negru"]
# Out:
# 'salut'

# %%
dictionar["salut"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 dictionar["salut"]
#
# KeyError: 'salut'

# %%
dictionar = { "rosu" : 1,
              "verde" : 2,
                "mov": 3,
            "negru" : "salut",
            "albastru" : True,
                "alb": 3.0}

for i in dictionar:
    print("cheia=", i, "valoarea:", dictionar[i] )
# Out:
# cheia= rosu valoarea: 1
# cheia= verde valoarea: 2
# cheia= mov valoarea: 3
# cheia= negru valoarea: salut
# cheia= albastru valoarea: True
# cheia= alb valoarea: 3.0
