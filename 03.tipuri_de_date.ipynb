# %% [markdown]
# Tipuri de date primitive : bool, int, float, str

# %% [markdown]
# Python este un limbaj - loosly typed

# %% [markdown]
# # Bool - boolean

# %%
x = True  # echivalent cu 1
x
# Out:
# True

# %%
x = False  # echivalent cu 0
x
# Out:
# False

# %%
int(x)
# Out:
# 0

# %%
type(x)
# Out:
# bool

# %% [markdown]
# # Int - integer

# %%
x = 10
x
# Out:
# 10

# %%
type(x)
# Out:
# int

# %%
x + 2
# Out:
# 12

# %% [markdown]
# # Float. - floating number

# %%
x = 10.32
x
# Out:
# 10.32

# %%
type(x)
# Out:
# float

# %%
2 + 3.032
# Out:
# 5.032

# %% [markdown]
# # Str - string

# %%
x = '32'
x
# Out:
# '32'

# %%
print(x)
# Out:
# 32

# %%
x = "32"
x
# Out:
# '32'

# %%
x = "apa"
x
# Out:
# 'apa'
